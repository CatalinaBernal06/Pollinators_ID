# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir("drive/Shared drives/Detección de polinizadores/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-86ffae389c94> in <cell line: 2>()
#       1 import os
# ----> 2 os.chdir("drive/Shared drives/Detección de polinizadores/")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'drive/Shared drives/Detección de polinizadores/'

# %%
# !ls
# Out:
# Código	Datos  Documentos  iNaturalist	Literatura  Presentaciones

# %%
df = pd.read_csv('iNaturalist/observations-484476_Diglossa.csv')
print(df.shape)
df.head()
# Out:
# (3168, 39)
#        id    observed_on_string observed_on           time_observed_at  \
# 0   63787  April 05, 2012 17:49  2012-04-05  2012-04-06 02:49:00 +0200
# 1  444151   2013-10-30 06:16:08  2013-10-30  2013-10-30 14:16:08 +0100
# 2  448348   2013-10-30 07:23:34  2013-10-30  2013-10-30 13:23:34 +0100
# 3  448354   2013-10-30 08:15:00  2013-10-30  2013-10-30 14:15:00 +0100
# 4  451706   2013-11-02 05:59:01  2013-11-02  2013-11-02 11:59:01 +0100
#
#                     time_zone  user_id user_login      user_name  \
# 0  Pacific Time (US & Canada)      477     loarie   Scott Loarie
# 1  Pacific Time (US & Canada)      477     loarie   Scott Loarie
# 2                      Bogota        1      kueda  Ken-ichi Ueda
# 3                      Bogota        1      kueda  Ken-ichi Ueda
# 4                      Bogota        1      kueda  Ken-ichi Ueda
#
#                   created_at                 updated_at  ... geoprivacy  \
# ...

# %%
df = df[(df.image_url.str.contains('http', na=False))].reset_index(drop=True)

# %%
df.shape
# Out:
# (3168, 39)

# %%
import requests


e = 0
for i in range(len(df)):

    try:
        # URL de la imagen
        image_url = df['image_url'].iloc[i]

        image_name = f'iNaturalist/Diglossa/Diglossa_{i}.jpg'

        response = requests.get(image_url)

        if response.status_code == 200:

            with open(image_name, 'wb') as file:
                file.write(response.content)
            #print(f"Imagen guardada como {image_name}")
            e +=1
        else:
            print(f"Error al descargar la imagen {i}. Código de estado: {response.status_code}")

    except:
        print('F', i)
        continue
